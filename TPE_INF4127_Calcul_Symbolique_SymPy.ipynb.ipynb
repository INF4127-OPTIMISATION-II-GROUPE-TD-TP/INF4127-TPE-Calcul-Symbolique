# %% [markdown]
# <div align="center">
#
# # 🎓 TPE: Calcul Symbolique avec SymPy
#
# ## INF4127 - Optimisation 2
#
# <br>
#
# <table style="border: 2px solid #2c3e50; border-radius: 10px; padding: 20px; background: linear-gradient(135deg, #f8f9fa 0%, #e9ecef 100%); width: 80%; margin: 0 auto;">
#   <tr>
#     <td colspan="3" style="text-align: center; padding: 15px; background: #2c3e50; color: white; border-radius: 8px;">
#       <strong>👥 ÉQUIPE DU PROJET</strong>
#     </td>
#   </tr>
#   <tr style="background: #3498db; color: white;">
#     <th style="padding: 12px; text-align: left;">Nom & Prénom</th>
#     <th style="padding: 12px; text-align: center;">Matricule</th>
#     <th style="padding: 12px; text-align: center;">Rôle</th>
#   </tr>
#   <tr style="background: #ffffff;">
#     <td style="padding: 10px; border-bottom: 1px solid #ddd;">ESSUTHI MBANGUE ANGE ARMEL</td>
#     <td style="padding: 10px; border-bottom: 1px solid #ddd; text-align: center;">24F2456</td>
#     <td style="padding: 10px; border-bottom: 1px solid #ddd; text-align: center;">Membre</td>
#   </tr>
#   <tr style="background: #f8f9fa;">
#     <td style="padding: 10px; border-bottom: 1px solid #ddd;">TAGNE TALLA IDRISS CHANEL</td>
#     <td style="padding: 10px; border-bottom: 1px solid #ddd; text-align: center;">19M2351</td>
#     <td style="padding: 10px; border-bottom: 1px solid #ddd; text-align: center;">Membre</td>
#   </tr>
#   <tr style="background: #ffffff;">
#     <td style="padding: 10px; border-bottom: 1px solid #ddd;">DJATCHE NKAMGANG SYLVANO</td>
#     <td style="padding: 10px; border-bottom: 1px solid #ddd; text-align: center;">22W2163</td>
#     <td style="padding: 10px; border-bottom: 1px solid #ddd; text-align: center;">Membre</td>
#   </tr>
#   <tr style="background: #f8f9fa;">
#     <td style="padding: 10px;">GOUJOU GUIMATSA ZIDANE</td>
#     <td style="padding: 10px; text-align: center;">21T2899</td>
#     <td style="padding: 10px; text-align: center;">Membre</td>
#   </tr>
# </table>
#
# <br>
#
# <div style="background: #e8f4f8; padding: 15px; border-radius: 8px; border-left: 4px solid #2980b9; width: 80%; margin: 0 auto;">
#   <strong>🎓 Encadrement Académique</strong><br>
#   <strong>Professeur Encadreur:</strong> Pr. MELATAGIA YONTA PAULIN<br>
#   <strong>Institution:</strong> Université de Yaoundé 1<br>
#   <strong>Département:</strong> Informatique<br>
#   <strong>Année Académique:</strong> 2024-2025
# </div>
#
# <br>
#
# <div style="background: #e8f5e8; padding: 12px; border-radius: 8px; width: 80%; margin: 0 auto;">
#   <strong>📚 Contexte:</strong> Travail Personnel Encadré dans le cadre du cours <strong>INF4127 - Optimisation 2</strong>
# </div>
#
# </div>
#
# <br>
#
# ---
#
# ## 📋 Table des Matières
#
# 1. [Introduction](#-introduction)
# 2. [Bloc 1: Installation et Importation](#-bloc-1-installation-et-importation-des-bibliothèques)
# 3. [Bloc 2: Symboles Mathématiques](#-bloc-2-création-des-symboles-mathématiques)
# 4. [Bloc 3: Calcul Exact](#-bloc-3-calcul-exact-avec-fractions-et-constantes)
# 5. [Bloc 4: Manipulation Algébrique](#-bloc-4-manipulation-algébrique-des-expressions)
# 6. [Bloc 5: Calcul Différentiel](#-bloc-5-calcul-différentiel-dérivées)
# 7. [Bloc 6: Gradient et Dérivées Partielles](#-bloc-6-gradient-et-dérivées-partielles-multivarié)
# 8. [Bloc 7: Comparaison Symbolique vs Numérique](#-bloc-7-comparaison-dérivée-symbolique-vs-numérique)
# 9. [Bloc 8: Conversion avec Lambdify](#-bloc-8-conversion-symbolique--numérique-avec-lambdify)
# 10. [Bloc 9: Visualisation](#-bloc-9-visualisation-des-résultats)
# 11. [Bloc 10: Applications en Optimisation](#-bloc-10-applications-en-optimisation)
# 12. [Conclusion](#-conclusion)

# %% [markdown]
# # 📚 TPE: Calcul Symbolique avec SymPy - Guide des Blocs
#
# ##  BLOC 1: Installation et Importation des Bibliothèques
#
# ### POURQUOI CE BLOC ?
# Ce bloc est le point de départ essentiel qui initialise tout l'environnement de travail. Sans ces bibliothèques, aucun calcul symbolique n'est possible. Il prépare l'écosystème complet nécessaire au TPE.
#
# ### À QUOI ÇA SERT ?
# - Initialiser l'environnement Python avec les bibliothèques spécialisées
# - Importer SymPy pour le calcul symbolique (cœur du projet)
# - Importer NumPy pour les calculs numériques complémentaires
# - Importer Matplotlib pour la visualisation des résultats
# - Configurer l'affichage mathématique professionnel (notation LaTeX)
# - Vérifier que l'installation est fonctionnelle avant de commencer
#
# ---
#
# ##  BLOC 2: Création des Symboles Mathématiques
#
# ### POURQUOI CE BLOC ?
# Les symboles sont la fondation du calcul symbolique. Contrairement aux variables numériques classiques, les symboles SymPy représentent des entités mathématiques abstraites qui conservent leur nature symbolique tout au long des calculs.
#
# ### À QUOI ÇA SERT ?
# - Créer des variables mathématiques abstraites (x, y, z...)
# - Définir des propriétés spécifiques (nombres réels, entiers, positifs)
# - Construire des expressions algébriques complexes
# - Établir la base pour toutes les manipulations symboliques ultérieures
# - Comprendre la différence fondamentale entre variables symboliques et numériques
#
# ---
#
# ##  BLOC 3: Calcul Exact avec Fractions et Constantes
#
# ### POURQUOI CE BLOC ?
# Ce bloc démontre l'avantage principal du calcul symbolique : la précision exacte. Il montre pourquoi SymPy est supérieur pour les calculs nécessitant une exactitude mathématique parfaite.
#
# ### À QUOI ÇA SERT ?
# - Manipuler des fractions de façon exacte (pas d'approximations décimales)
# - Traiter les constantes mathématiques (π, √2, e) symboliquement
# - Comparer calcul exact vs calcul approximatif
# - Comprendre l'accumulation d'erreurs dans les calculs numériques
# - Préserver la forme mathématique exacte tout au long des calculs
#
# ---
#
# ##  BLOC 4: Manipulation Algébrique des Expressions
#
# ### POURQUOI CE BLOC ?
# Ce bloc illustre la puissance de SymPy pour transformer et simplifier les expressions mathématiques automatiquement, reproduisant le travail algébrique qu'un mathématicien ferait manuellement.
#
# ### À QUOI ÇA SERT ?
# - Développer des expressions polynomiales complexes
# - Factoriser des polynômes en produits simples
# - Simplifier des expressions rationnelles et trigonométriques
# - Réorganiser des expressions selon des variables spécifiques
# - Automatiser les manipulations algébriques fastidieuses
#
# ---
#
# ##  BLOC 5: Calcul Différentiel (Dérivées)
#
# ### POURQUOI CE BLOC ?
# Le calcul différentiel est fondamental en optimisation. Ce bloc montre comment SymPy calcule des dérivées de façon exacte et automatique, éliminant les erreurs de calcul manuel.
#
# ### À QUOI ÇA SERT ?
# - Calculer des dérivées exactes de fonctions complexes
# - Obtenir des dérivées d'ordre supérieur (2ème, 3ème dérivée)
# - Appliquer automatiquement les règles de dérivation (produit, quotient, chaîne)
# - Évaluer des dérivées en des points spécifiques
# - Préparer le terrain pour l'optimisation (recherche d'extremums)
#
# ---
#
# ##  BLOC 6: Gradient et Dérivées Partielles (Multivarié)
#
# ### POURQUOI CE BLOC ?
# L'optimisation en dimensions supérieures nécessite le calcul de gradients et de matrices hessiennes. Ce bloc est crucial pour les applications en optimisation multivariée du cours INF4127.
#
# ### À QUOI ÇA SERT ?
# - Calculer des dérivées partielles pour fonctions à plusieurs variables
# - Construire le vecteur gradient (∇f)
# - Former la matrice hessienne (dérivées secondes)
# - Évaluer gradients et hessiennes en points spécifiques
# - Préparer l'analyse des points critiques en optimisation
#
# ---
#
# ##  BLOC 7: Comparaison: Dérivée Symbolique vs Numérique
#
# ### POURQUOI CE BLOC ?
# Ce bloc pédagogique montre concrètement la différence fondamentale entre l'approche symbolique (exacte) et numérique (approximative), justifiant le choix du calcul symbolique pour certaines applications.
#
# ### À QUOI ÇA SERT ?
# - Comparer les résultats exacts vs approximatifs
# - Mesurer les erreurs d'approximation numérique
# - Comprendre l'impact du choix du pas h en différences finies
# - Justifier l'utilisation du calcul symbolique pour la précision
# - Illustrer les compromis précision/performance
#
# ---
#
# ##  BLOC 8: Conversion Symbolique → Numérique avec Lambdify
#
# ### POURQUOI CE BLOC ?
# Ce bloc est le pont essentiel entre le monde symbolique et numérique. Il montre comment profiter des deux approches : exactitude symbolique + performance numérique.
#
# ### À QUOI ÇA SERT ?
# - Convertir des expressions symboliques en fonctions numériques optimisées
# - Réaliser des calculs vectorisés rapides sur des tableaux
# - Combiner la précision symbolique avec la performance numérique
# - Préparer des fonctions pour la visualisation et l'analyse numérique
# - Comprendre l'interopérabilité entre SymPy et NumPy
#
# ---
#
# ##  BLOC 9: Visualisation des Résultats
#
# ### POURQUOI CE BLOC ?
# La visualisation est cruciale pour interpréter les résultats mathématiques. Ce bloc transforme des expressions abstraites en représentations graphiques concrètes.
#
# ### À QUOI ÇA SERT ?
# - Visualiser des fonctions mathématiques complexes
# - Superposer fonctions et leurs dérivées pour l'analyse
# - Représenter graphiquement les erreurs d'approximation
# - Créer des graphiques professionnels pour rapports et présentations
# - Faciliter l'interprétation intuitive des résultats mathématiques
#
# ---
#
# ##  BLOC 10: Applications en Optimisation
#
# ### POURQUOI CE BLOC ?
# Ce bloc est le point culminant qui relie tous les concepts à l'optimisation (cours INF4127). Il montre l'application pratique du calcul symbolique pour résoudre des problèmes d'optimisation réels.
#
# ### À QUOI ÇA SERT ?
# - Résoudre des problèmes d'optimisation unidimensionnels
# - Analyser des fonctions multivariées avec gradient et hessienne
# - Implémenter la méthode du Lagrangien pour contraintes
# - Classifier les points critiques (minima, maxima, points selle)
# - Résoudre un problème concret d'optimisation de volume
# - Appliquer directement les techniques du cours INF4127
#
# ---
#
# ##  CONCLUSION GÉNÉRALE
#
# ### POURQUOI CE TPE ?
# Ce travail démontre l'utilité pratique du calcul symbolique dans le contexte de l'optimisation mathématique, en montrant comment SymPy permet d'automatiser et de garantir l'exactitude des calculs fondamentaux pour INF4127.
#
# ### ACQUIS PRINCIPAUX :
# - Maîtrise du calcul symbolique avec SymPy
# - Compréhension profonde de l'optimisation mathématique
# - Capacité à résoudre des problèmes concrets d'optimisation
# - Compétences en visualisation scientifique
# - Interfaçage entre calcul symbolique et numérique

# %% [markdown]
# ## BLOC 1: Installation et Importation des Bibliothèques

# %%
# BLOC 1: Installation et importation des bibliothèques
try:
    import sympy as sp
    import numpy as np
    import matplotlib.pyplot as plt
    print(" Bibliothèques déjà installées")
except ImportError as e:
    print(f" Bibliothèque manquante: {e}")
    print(" Installation en cours...")
    # !pip install sympy numpy matplotlib
    import sympy as sp
    import numpy as np
    import matplotlib.pyplot as plt

# Configuration pour l'affichage mathématique
sp.init_printing(use_latex=True)

# Importation des fonctions spécifiques
from sympy import symbols, diff, integrate, limit, solve, expand, factor, simplify
from sympy import sin, cos, tan, exp, log, sqrt, pi, Rational, Matrix
from sympy.plotting import plot

print(" Toutes les bibliothèques sont importées avec succès!")
print(f" Version SymPy: {sp.__version__}")
# Out:
#  Bibliothèques déjà installées
#  Toutes les bibliothèques sont importées avec succès!
#  Version SymPy: 1.13.2

# %% [markdown]
# ## BLOC 2: Création des Symboles Mathématiques

# %%
# BLOC 2: Création des symboles
print(" CRÉATION DES SYMBOLES MATHÉMATIQUES")

# Création de symboles simples
x, y, z = symbols('x y z')
print(f" Symboles créés: x = {x}, y = {y}, z = {z}")
print(f" Type de x: {type(x)}")

# Création de symboles avec propriétés spécifiques
a, b, c = symbols('a b c', real=True)  # Nombres réels
n, m = symbols('n m', integer=True)    # Nombres entiers
print(f" Symboles réels: a = {a}, b = {b}, c = {c}")
print(f" Symboles entiers: n = {n}, m = {m}")

# Test d'expression simple
expr_test = x**2 + 2*x + 1
print(f" Expression test: {expr_test}")

# Vérification que les symboles fonctionnent
print(f" Substitution x=3: {expr_test.subs(x, 3)}")
# Out:
#  CRÉATION DES SYMBOLES MATHÉMATIQUES
#  Symboles créés: x = x, y = y, z = z
#  Type de x: <class 'sympy.core.symbol.Symbol'>
#  Symboles réels: a = a, b = b, c = c
#  Symboles entiers: n = n, m = m
#  Expression test: x**2 + 2*x + 1
#  Substitution x=3: 16

# %% [markdown]
# ## BLOC 3: Calcul Exact avec Fractions et Constantes

# %%
# BLOC 3: Calcul exact vs approximation numérique
print(" CALCUL EXACT VS APPROXIMATION NUMÉRIQUE")

# Expression avec fractions exactes
expr_exact = (x + 1)**2 / Rational(2, 3) + sqrt(2)
print(f" Expression exacte: {expr_exact}")

# Évaluation numérique avec haute précision
exact_value = expr_exact.subs(x, 1).evalf(15)
print(f" Valeur exacte en x=1: {exact_value}")

# Comparaison avec l'approximation flottante
approx_float = (1 + 1)**2 / (2/3) + 1.4142135623730951
print(f" Approximation flottante: {approx_float}")

# Calcul de l'erreur
error = abs(exact_value - approx_float)
print(f" Erreur d'approximation: {error}")

# Test avec π
print(f"\n Test avec π:")
print(f"π exact (SymPy): {pi}")
print(f"π approximé (math): {np.pi}")
print(f"Différence: {abs(pi.evalf(15) - np.pi)}")

# Test avec une autre expression
expr_complexe = (sqrt(2) + sqrt(3)) / Rational(1, 2)
print(f"\n Expression complexe: {expr_complexe}")
print(f"Valeur numérique: {expr_complexe.evalf(10)}")
# Out:
#  CALCUL EXACT VS APPROXIMATION NUMÉRIQUE
#  Expression exacte: 3*(x + 1)**2/2 + sqrt(2)
#  Valeur exacte en x=1: 7.41421356237309
#  Approximation flottante: 7.414213562373095
#  Erreur d'approximation: 0
#
#  Test avec π:
# π exact (SymPy): pi
# π approximé (math): 3.141592653589793
# Différence: 0
#
#  Expression complexe: 2*sqrt(2) + 2*sqrt(3)
# Valeur numérique: 6.292528740

# %% [markdown]
# ## BLOC 4: Manipulation Algébrique des Expressions

# %%
# BLOC 4: Manipulation algébrique
print(" MANIPULATION ALGÉBRIQUE")

# Exemple 1: Développement
expr_dev = (x + 1)**3
developpe = expand(expr_dev)
print(f" Développement de (x+1)³: {developpe}")

# Exemple 2: Factorisation
expr_fac = x**3 + 3*x**2 + 3*x + 1
factorise = factor(expr_fac)
print(f" Factorisation de x³+3x²+3x+1: {factorise}")

# Exemple 3: Simplification
expr_simp = (x**2 - 1)/(x - 1)
simplifie = simplify(expr_simp)
print(f" Simplification de (x²-1)/(x-1): {simplifie}")

# Exemple 4: Collecte de termes
expr_collect = x*y + x - 3 + 2*x**2 - x**2*y
collecte_x = sp.collect(expr_collect, x)
collecte_y = sp.collect(expr_collect, y)
print(f" Collecte par rapport à x: {collecte_x}")
print(f" Collecte par rapport à y: {collecte_y}")

# Exemple 5: Test avec une expression plus complexe
expr_complexe = (x**2 - y**2) / (x - y) + (x**3 - 1) / (x - 1)
simplifie_complexe = simplify(expr_complexe)
print(f"\n Expression complexe: {expr_complexe}")
print(f" Simplifiée: {simplifie_complexe}")
# Out:
#  MANIPULATION ALGÉBRIQUE
#  Développement de (x+1)³: x**3 + 3*x**2 + 3*x + 1
#  Factorisation de x³+3x²+3x+1: (x + 1)**3
#  Simplification de (x²-1)/(x-1): x + 1
#  Collecte par rapport à x: x**2*(2 - y) + x*(y + 1) - 3
#  Collecte par rapport à y: 2*x**2 + x + y*(-x**2 + x) - 3
#
#  Expression complexe: (x**2 - y**2)/(x - y) + (x**3 - 1)/(x - 1)
#  Simplifiée: x**2 + 2*x + y + 1

# %% [markdown]
# ## BLOC 5: Calcul Différentiel (Dérivées)

# %%
# BLOC 5: Calcul différentiel
print(" CALCUL DIFFÉRENTIEL - DÉRIVÉES")

# Dérivée simple
f = sin(x)*x
f_prime = diff(f, x)
print(f" Fonction: f(x) = {f}")
print(f" Dérivée: f'(x) = {f_prime}")

# Évaluation en un point
x_point = 1.0
valeur_exacte = f_prime.subs(x, x_point).evalf()
print(f" f'({x_point}) exact = {valeur_exacte}")

# Dérivées d'ordre supérieur
f_seconde = diff(f, x, 2)
f_troisieme = diff(f, x, 3)
print(f" Dérivée seconde: f''(x) = {f_seconde}")
print(f" Dérivée troisième: f'''(x) = {f_troisieme}")

# Test avec une fonction plus complexe
f_complexe = exp(x) * cos(x)
f_complexe_prime = diff(f_complexe, x)
print(f"\n Fonction complexe: {f_complexe}")
print(f" Dérivée: {f_complexe_prime}")

# Test avec règle de chaîne
f_chain = sin(x**2 + 1)
f_chain_prime = diff(f_chain, x)
print(f"\n  Fonction avec composition: {f_chain}")
print(f" Dérivée (règle de chaîne): {f_chain_prime}")

# Vérification de la règle de produit
print(f"\n Vérification règle de produit:")
print(f"d/dx [sin(x)*x] = cos(x)*x + sin(x)*1")
print(f"Résultat SymPy: {f_prime}")
# Out:
#  CALCUL DIFFÉRENTIEL - DÉRIVÉES
#  Fonction: f(x) = x*sin(x)
#  Dérivée: f'(x) = x*cos(x) + sin(x)
#  f'(1.0) exact = 1.38177329067604
#  Dérivée seconde: f''(x) = -x*sin(x) + 2*cos(x)
#  Dérivée troisième: f'''(x) = -(x*cos(x) + 3*sin(x))
#
#  Fonction complexe: exp(x)*cos(x)
#  Dérivée: -exp(x)*sin(x) + exp(x)*cos(x)
#
#   Fonction avec composition: sin(x**2 + 1)
#  Dérivée (règle de chaîne): 2*x*cos(x**2 + 1)
#
#  Vérification règle de produit:
# d/dx [sin(x)*x] = cos(x)*x + sin(x)*1
# Résultat SymPy: x*cos(x) + sin(x)

# %% [markdown]
# ## BLOC 6: Gradient et Dérivées Partielles (Multivarié)

# %%
# BLOC 6: Gradient et dérivées partielles
print(" GRADIENT ET DÉRIVÉES PARTIELLES")

# Fonction de deux variables
f_multi = x**2 * y**3 + cos(x)
print(f" Fonction multivariée: f(x,y) = {f_multi}")

# Dérivées partielles
df_dx = diff(f_multi, x)
df_dy = diff(f_multi, y)
print(f" Dérivée partielle ∂f/∂x = {df_dx}")
print(f" Dérivée partielle ∂f/∂y = {df_dy}")

# Gradient (vecteur des dérivées partielles)
gradient = [df_dx, df_dy]
print(f" Gradient ∇f = {gradient}")

# Évaluation en un point (1, 2)
point = {x: 1, y: 2}
gradient_point = [df.subs(point).evalf() for df in gradient]
print(f" Gradient en (1,2): {gradient_point}")

# Dérivées partielles secondes
d2f_dx2 = diff(f_multi, x, 2)
d2f_dy2 = diff(f_multi, y, 2)
d2f_dxdy = diff(f_multi, x, y)
print(f"\n Dérivée seconde ∂²f/∂x² = {d2f_dx2}")
print(f" Dérivée seconde ∂²f/∂y² = {d2f_dy2}")
print(f" Dérivée croisée ∂²f/∂x∂y = {d2f_dxdy}")

# Matrice Hessienne
hessienne = sp.Matrix([
    [d2f_dx2, d2f_dxdy],
    [d2f_dxdy, d2f_dy2]
])
print(f"\n Matrice Hessienne:")
sp.pprint(hessienne)

# Test avec une autre fonction
print(f"\n TEST AVEC FONCTION QUADRATIQUE:")
f_quad = a*x**2 + b*x*y + c*y**2
print(f"f(x,y) = {f_quad}")
grad_quad = [diff(f_quad, x), diff(f_quad, y)]
print(f"Gradient: {grad_quad}")
# Out:
#  GRADIENT ET DÉRIVÉES PARTIELLES
#  Fonction multivariée: f(x,y) = x**2*y**3 + cos(x)
#  Dérivée partielle ∂f/∂x = 2*x*y**3 - sin(x)
#  Dérivée partielle ∂f/∂y = 3*x**2*y**2
#  Gradient ∇f = [2*x*y**3 - sin(x), 3*x**2*y**2]
#  Gradient en (1,2): [15.1585290151921, 12.0000000000000]
#
#  Dérivée seconde ∂²f/∂x² = 2*y**3 - cos(x)
#  Dérivée seconde ∂²f/∂y² = 6*x**2*y
#  Dérivée croisée ∂²f/∂x∂y = 6*x*y**2
#
#  Matrice Hessienne:
# ⎡   3                2⎤
# ⎢2⋅y  - cos(x)  6⋅x⋅y ⎥
# ⎢                     ⎥
# ⎢        2         2  ⎥
# ⎣   6⋅x⋅y       6⋅x ⋅y⎦
#
#  TEST AVEC FONCTION QUADRATIQUE:
# f(x,y) = a*x**2 + b*x*y + c*y**2
# Gradient: [2*a*x + b*y, b*x + 2*c*y]

# %% [markdown]
# ## BLOC 7: Comparaison: Dérivée Symbolique vs Numérique

# %%
# BLOC 7: Comparaison symbolique vs numérique
print(" COMPARAISON: DÉRIVÉE SYMBOLIQUE VS NUMÉRIQUE")

# Méthode symbolique (exacte)
f_sym = sin(x)*x
f_prime_sym = diff(f_sym, x)
print(f" Dérivée symbolique exacte: {f_prime_sym}")

# Évaluation exacte
x_eval = 1.0
exact_deriv = f_prime_sym.subs(x, x_eval).evalf()
print(f" f'({x_eval}) exact = {exact_deriv}")

# Méthode numérique (approximation par différences finies)
def f_num(t):
    return t * np.sin(t)

h = 1e-6  # Pas très petit
approx_deriv = (f_num(x_eval + h) - f_num(x_eval)) / h
print(f" f'({x_eval}) approximé = {approx_deriv}")

# Calcul de l'erreur
erreur = abs(exact_deriv - approx_deriv)
print(f" Erreur d'approximation: {erreur}")
print(f" Pourcentage d'erreur: {erreur/abs(exact_deriv)*100:.6f}%")

# Test avec différentes valeurs de h
print("\n Test avec différents pas h:")
for h_test in [1e-4, 1e-6, 1e-8]:
    approx = (f_num(x_eval + h_test) - f_num(x_eval)) / h_test
    erreur_test = abs(exact_deriv - approx)
    print(f"h = {h_test:.0e} → erreur = {erreur_test:.2e}")

# Test avec une fonction plus complexe
print(f"\n TEST AVEC FONCTION COMPLEXE:")
f_complex_sym = exp(-x/2) * sin(2*x)
f_complex_prime_sym = diff(f_complex_sym, x)
print(f"Fonction: {f_complex_sym}")
print(f"Dérivée exacte: {f_complex_prime_sym}")

# Conversion pour calcul numérique
f_complex_num = sp.lambdify(x, f_complex_sym, 'numpy')
x_test_complex = 2.0
exact_complex = f_complex_prime_sym.subs(x, x_test_complex).evalf()
approx_complex = (f_complex_num(x_test_complex + h) - f_complex_num(x_test_complex)) / h
print(f"f'({x_test_complex}) exact = {exact_complex}")
print(f"f'({x_test_complex}) approx = {approx_complex}")
print(f"Erreur: {abs(exact_complex - approx_complex):.2e}")
# Out:
#  COMPARAISON: DÉRIVÉE SYMBOLIQUE VS NUMÉRIQUE
#  Dérivée symbolique exacte: x*cos(x) + sin(x)
#  f'(1.0) exact = 1.38177329067604
#  f'(1.0) approximé = 1.3817734101362333
#  Erreur d'approximation: 1.19460197067767E-7
#  Pourcentage d'erreur: 0.000009%
#
#  Test avec différents pas h:
# h = 1e-04 → erreur = 1.20e-5
# h = 1e-06 → erreur = 1.19e-7
# h = 1e-08 → erreur = 6.00e-9
#
#  TEST AVEC FONCTION COMPLEXE:
# Fonction: exp(-x/2)*sin(2*x)
# Dérivée exacte: -exp(-x/2)*sin(2*x)/2 + 2*exp(-x/2)*cos(2*x)
# f'(2.0) exact = -0.341718060411651
# f'(2.0) approx = -0.3417172980135774
# Erreur: 7.62e-7

# %% [markdown]
# ## Conversion Symbolique → Numérique avec Lambdify

# %%
# BLOC 8 CORRIGÉ: Conversion avec lambdify
print(" CONVERSION SYMBOLIQUE → NUMÉRIQUE")

# Expression symbolique
f_sym = x**2 + sin(x)/x
print(f" Expression symbolique: {f_sym}")

# Conversion en fonction numérique
f_num = sp.lambdify(x, f_sym, 'numpy')
print(" Conversion réussie avec lambdify")

# Test sur un point
test_point = 2.0
resultat_point = f_num(test_point)
print(f" Test en x={test_point}: {resultat_point}")

# Test sur un tableau (calcul vectorisé)
x_array = np.linspace(0.1, 10, 5)  # Éviter x=0
y_array = f_num(x_array)
print(f" Évaluation vectorisée:")
print(f"x = {x_array}")
print(f"f(x) = {y_array}")

# Vérification avec calcul symbolique - CORRECTION ICI
print("\n Vérification avec calcul symbolique:")
for x_val in x_array:
    sym_val = float(f_sym.subs(x, x_val).evalf())  # Conversion en float
    num_val = f_num(x_val)
    erreur = abs(sym_val - num_val)
    print(f"x={x_val:.1f}: symbolique={sym_val:.6f}, numérique={num_val:.6f}, erreur={erreur:.2e}")

# Test avec fonction multivariée
print(f"\n TEST FONCTION MULTIVARIÉE:")
f_multi_sym = x**2 + x*y + y**2
print(f"f(x,y) = {f_multi_sym}")

# Conversion pour deux variables
f_multi_num = sp.lambdify((x, y), f_multi_sym, 'numpy')
test_x, test_y = 2.0, 3.0
result_multi = f_multi_num(test_x, test_y)
print(f"f({test_x}, {test_y}) = {result_multi}")

# Vérification symbolique - CORRECTION ICI
verif_multi = float(f_multi_sym.subs({x: test_x, y: test_y}).evalf())  # Conversion en float
print(f"Vérification symbolique: {verif_multi}")
print(f"Erreur: {abs(verif_multi - result_multi):.2e}")

# Performance test
print(f"\n TEST DE PERFORMANCE:")
import time

x_large = np.linspace(1, 100, 10000)

# Temps calcul symbolique (point par point) - CORRECTION ICI
start_time = time.time()
results_sym = [float(f_sym.subs(x, val).evalf()) for val in x_large[:10]]  # Juste 10 points + conversion
time_sym = time.time() - start_time

# Temps calcul numérique (vectorisé)
start_time = time.time()
results_num = f_num(x_large)
time_num = time.time() - start_time

print(f"Temps calcul symbolique (10 points): {time_sym:.4f}s")
print(f"Temps calcul numérique (10000 points): {time_num:.4f}s")
print(f"Accélération: {time_sym/(time_num/1000):.0f}x plus rapide")
# Out:
#  CONVERSION SYMBOLIQUE → NUMÉRIQUE
#  Expression symbolique: x**2 + sin(x)/x
#  Conversion réussie avec lambdify
#  Test en x=2.0: 4.4546487134128405
#  Évaluation vectorisée:
# x = [ 0.1    2.575  5.05   7.525 10.   ]
# f(x) = [ 1.00833417  6.83907559 25.31565868 56.7513887  99.94559789]
#
#  Vérification avec calcul symbolique:
# x=0.1: symbolique=1.008334, numérique=1.008334, erreur=0.00e+00
# x=2.6: symbolique=6.839076, numérique=6.839076, erreur=0.00e+00
# x=5.0: symbolique=25.315659, numérique=25.315659, erreur=0.00e+00
# x=7.5: symbolique=56.751389, numérique=56.751389, erreur=0.00e+00
# x=10.0: symbolique=99.945598, numérique=99.945598, erreur=0.00e+00
#
#  TEST FONCTION MULTIVARIÉE:
# f(x,y) = x**2 + x*y + y**2
# f(2.0, 3.0) = 19.0
# Vérification symbolique: 19.0
# Erreur: 0.00e+00
#
#  TEST DE PERFORMANCE:
# Temps calcul symbolique (10 points): 0.0025s
# Temps calcul numérique (10000 points): 0.0006s
# Accélération: 4262x plus rapide

# %% [markdown]
# ##  BLOC 9: Visualisation des Résultats

# %%
# BLOC 9: Visualisation
print(" VISUALISATION DES RÉSULTATS")

# Création d'une fonction intéressante à visualiser
f_visu = exp(-x/2) * sin(2*x)
print(f" Fonction à visualiser: {f_visu}")

# Conversion en fonction numérique
f_visu_num = sp.lambdify(x, f_visu, 'numpy')

# Création des données
x_vals = np.linspace(0, 4*np.pi, 500)
y_vals = f_visu_num(x_vals)

# Calcul de la dérivée pour superposition
f_visu_deriv = diff(f_visu, x)
f_visu_deriv_num = sp.lambdify(x, f_visu_deriv, 'numpy')
y_deriv_vals = f_visu_deriv_num(x_vals)

# Tracé
plt.figure(figsize=(12, 8))

# Sous-graphique 1: Fonction et sa dérivée
plt.subplot(2, 1, 1)
plt.plot(x_vals, y_vals, 'b-', linewidth=2, label=r'$f(x) = e^{-x/2} \sin(2x)$')
plt.plot(x_vals, y_deriv_vals, 'r--', linewidth=2, label=r"$f'(x)$")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Fonction et sa dérivée')
plt.legend()
plt.grid(True, alpha=0.3)

# Sous-graphique 2: Erreur relative
plt.subplot(2, 1, 2)
# Simulation d'approximation numérique pour comparaison
h_viz = 0.1
approx_deriv_viz = (f_visu_num(x_vals + h_viz) - f_visu_num(x_vals)) / h_viz
erreur_relative = np.abs((y_deriv_vals - approx_deriv_viz) / (y_deriv_vals + 1e-10))

plt.semilogy(x_vals, erreur_relative, 'g-', linewidth=1, label='Erreur relative')
plt.xlabel('x')
plt.ylabel('Erreur relative')
plt.title('Erreur de l\'approximation numérique')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(" Visualisation terminée")
print(f" Dérivée exacte: {f_visu_deriv}")

# Test d'affichage d'expressions complexes
print(f"\n TEST AFFICHAGE SYMBOLIQUE:")
expr_complexe = (sin(x)**2 + cos(x)**2) / (x**2 + 1)
print(f"Expression: {expr_complexe}")
print(f"Simplifiée: {simplify(expr_complexe)}")
# Out:
#  VISUALISATION DES RÉSULTATS
#  Fonction à visualiser: exp(-x/2)*sin(2*x)
#  Visualisation terminée
#  Dérivée exacte: -exp(-x/2)*sin(2*x)/2 + 2*exp(-x/2)*cos(2*x)
#
#  TEST AFFICHAGE SYMBOLIQUE:
# Expression: (sin(x)**2 + cos(x)**2)/(x**2 + 1)
# Simplifiée: 1/(x**2 + 1)

# %% [markdown]
# ## BLOC 10: Applications en Optimisation

# %%
# BLOC 10 CORRIGÉ 2: Applications en optimisation
print(" APPLICATIONS EN OPTIMISATION")

# Exemple 1: Optimisation d'une fonction simple
print("1. OPTIMISATION D'UNE FONCTION SIMPLE")
f_opt = x**3 - 6*x**2 + 9*x + 1
print(f" Fonction à optimiser: f(x) = {f_opt}")

# Dérivée première (condition nécessaire)
f_prime = diff(f_opt, x)
print(f" Dérivée: f'(x) = {f_prime}")

# Points critiques
critical_points = solve(f_prime, x)
print(f" Points critiques: {critical_points}")

# Dérivée seconde (test)
f_double_prime = diff(f_opt, x, 2)
print(f" Dérivée seconde: f''(x) = {f_double_prime}")

# Classification des points critiques
print("\n CLASSIFICATION DES POINTS CRITIQUES:")
for point in critical_points:
    second_deriv = f_double_prime.subs(x, point)
    f_value = f_opt.subs(x, point)
    
    if second_deriv > 0:
        point_type = "minimum local"
    elif second_deriv < 0:
        point_type = "maximum local"
    else:
        point_type = "point d'inflexion"
    
    print(f"x = {point}: f(x) = {float(f_value):.2f}, {point_type}")

# Exemple 2: Optimisation multivariée
print(f"\n2. OPTIMISATION MULTIVARIÉE")
f_multi_opt = x**2 + x*y + y**2 - 4*x - 5*y
print(f" Fonction multivariée: f(x,y) = {f_multi_opt}")

# Gradient
gradient = [diff(f_multi_opt, var) for var in (x, y)]
print(f" Gradient:")
print(f"∂f/∂x = {gradient[0]}")
print(f"∂f/∂y = {gradient[1]}")

# Points critiques - CORRECTION ICI
critical_points_multi = solve(gradient, (x, y))
print(f" Points critiques: {critical_points_multi}")

# Matrice Hessienne
hessian = sp.Matrix([
    [diff(f_multi_opt, x, x), diff(f_multi_opt, x, y)],
    [diff(f_multi_opt, y, x), diff(f_multi_opt, y, y)]
])
print(f" Matrice Hessienne:")
sp.pprint(hessian)

# Classification des points critiques multivariés - CORRECTION COMPLÈTE
print(f"\n CLASSIFICATION MULTIVARIÉE:")
if critical_points_multi:
    # Si on a un seul point critique
    if isinstance(critical_points_multi, dict):
        point_dict = critical_points_multi
        x_val = point_dict[x]
        y_val = point_dict[y]
        
        # Évaluation de la Hessienne au point critique
        hessian_point = hessian.subs(point_dict)
        det_hessian = hessian_point.det()
        f_value = f_multi_opt.subs(point_dict)
        
        if det_hessian > 0:
            if hessian_point[0, 0] > 0:
                point_type = "minimum local"
            else:
                point_type = "maximum local"
        elif det_hessian < 0:
            point_type = "point selle"
        else:
            point_type = "indéterminé"
        
        print(f"Point ({x_val}, {y_val}): f = {float(f_value):.2f}, {point_type}")
    
    # Si on a plusieurs points critiques (liste de dict)
    elif isinstance(critical_points_multi, list):
        for point_dict in critical_points_multi:
            x_val = point_dict[x]
            y_val = point_dict[y]
            
            # Évaluation de la Hessienne au point critique
            hessian_point = hessian.subs(point_dict)
            det_hessian = hessian_point.det()
            f_value = f_multi_opt.subs(point_dict)
            
            if det_hessian > 0:
                if hessian_point[0, 0] > 0:
                    point_type = "minimum local"
                else:
                    point_type = "maximum local"
            elif det_hessian < 0:
                point_type = "point selle"
            else:
                point_type = "indéterminé"
            
            print(f"Point ({x_val}, {y_val}): f = {float(f_value):.2f}, {point_type}")
else:
    print("Aucun point critique trouvé")

# Exemple 3: Optimisation avec contrainte (Lagrangien)
print(f"\n3. OPTIMISATION SOUS CONTRAINTE")
# Maximiser f(x,y) = x*y sous contrainte x + y = 10
f_obj = x * y
contrainte = x + y - 10

# Lagrangien
lambda_sym = symbols('lambda')
lagrangien = f_obj - lambda_sym * contrainte
print(f" Fonction objectif: {f_obj}")
print(f" Contrainte: {contrainte} = 0")
print(f" Lagrangien: L = {lagrangien}")

# Conditions KKT
grad_L = [diff(lagrangien, var) for var in (x, y, lambda_sym)]
print(f" Gradient du Lagrangien:")
for i, eq in enumerate(grad_L):
    print(f"∂L/∂{['x', 'y', 'λ'][i]} = {eq}")

# Résolution
solution_kkt = solve(grad_L, (x, y, lambda_sym))
print(f" Solution KKT: {solution_kkt}")

# Vérification
if solution_kkt:
    # Gérer différents formats de solution
    if isinstance(solution_kkt, dict):
        x_opt = solution_kkt[x]
        y_opt = solution_kkt[y]
    else:
        x_opt, y_opt, lambda_opt = list(solution_kkt[0])[:2]
    
    f_opt_value = f_obj.subs({x: x_opt, y: y_opt})
    print(f" Valeur optimale: f({x_opt}, {y_opt}) = {f_opt_value}")

# Exemple 4: Application pratique - optimisation de volume
print(f"\n4. APPLICATION PRATIQUE: OPTIMISATION DE VOLUME")
print("Problème: Trouver les dimensions d'une boîte sans couvercle de volume maximal avec surface fixe")

# Surface fixe = 12 m²
S = 12
# Dimensions: longueur = l, largeur = l, hauteur = h
l, h = symbols('l h', positive=True)

# Surface: fond (l²) + 4 côtés (l*h)
surface_eq = l**2 + 4*l*h - S
# Volume: V = l² * h
volume = l**2 * h

# Exprimer h en fonction de l depuis la contrainte de surface
h_expr = solve(surface_eq, h)[0]
print(f" Hauteur en fonction de la longueur: h = {h_expr}")

# Volume en fonction de l seulement
volume_l = volume.subs(h, h_expr)
print(f" Volume: V(l) = {volume_l}")

# Optimisation
dV_dl = diff(volume_l, l)
points_critiques = solve(dV_dl, l)
print(f" Points critiques: {points_critiques}")

# Sélectionner la solution positive
l_opt = [sol for sol in points_critiques if sol > 0][0]
h_opt = h_expr.subs(l, l_opt)
volume_opt = volume_l.subs(l, l_opt)

print(f" Solution optimale:")
print(f"  Longueur = {float(l_opt):.2f} m")
print(f"  Hauteur = {float(h_opt):.2f} m") 
print(f"  Volume maximal = {float(volume_opt):.2f} m³")

print(f"\n RÉSUMÉ DES AVANTAGES SYMPY POUR L'OPTIMISATION:")
print("✓ Calcul exact des gradients et hessiennes")
print("✓ Résolution analytique des conditions d'optimalité")
print("✓ Classification automatique des points critiques")
print("✓ Gestion des contraintes via Lagrangien")
print("✓ Applications pratiques directes pour INF4127")
# Out:
#  APPLICATIONS EN OPTIMISATION
# 1. OPTIMISATION D'UNE FONCTION SIMPLE
#  Fonction à optimiser: f(x) = x**3 - 6*x**2 + 9*x + 1
#  Dérivée: f'(x) = 3*x**2 - 12*x + 9
#  Points critiques: [1, 3]
#  Dérivée seconde: f''(x) = 6*(x - 2)
#
#  CLASSIFICATION DES POINTS CRITIQUES:
# x = 1: f(x) = 5.00, maximum local
# x = 3: f(x) = 1.00, minimum local
#
# 2. OPTIMISATION MULTIVARIÉE
#  Fonction multivariée: f(x,y) = x**2 + x*y - 4*x + y**2 - 5*y
#  Gradient:
# ∂f/∂x = 2*x + y - 4
# ∂f/∂y = x + 2*y - 5
#  Points critiques: {x: 1, y: 2}
#  Matrice Hessienne:
# ⎡2  1⎤
# ⎢    ⎥
# ⎣1  2⎦
#
#  CLASSIFICATION MULTIVARIÉE:
# Point (1, 2): f = -7.00, minimum local
#
# 3. OPTIMISATION SOUS CONTRAINTE
#  Fonction objectif: x*y
#  Contrainte: x + y - 10 = 0
#  Lagrangien: L = -lambda*(x + y - 10) + x*y
#  Gradient du Lagrangien:
# ∂L/∂x = -lambda + y
# ∂L/∂y = -lambda + x
# ∂L/∂λ = -x - y + 10
#  Solution KKT: {lambda: 5, x: 5, y: 5}
#  Valeur optimale: f(5, 5) = 25
#
# ...
